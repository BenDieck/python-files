# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\bendi\OneDrive\Documents\My.Master.Plan\IST 652 Scripting for Data\python_notebook

# %%
#Calculating rate of pay
#2023-10-16
#Ben Dieck
#Q3: Writing a Program 1

hours=input('Hours Worked:')
rate=input('Rate of Pay in Dollars:')

pay=float(hours)*float(rate)
print('Pay is:{:.2f}.'.format(pay))
# Out:
# Hours Worked:8.5
# Rate of Pay in Dollars:23.5
# Pay is:199.75.
