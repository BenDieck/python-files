# %%
m = True
n = 3.14
q = "−7.2345907654"
print (type(m))
print(type(n))
print(type(q))
# Out:
# <class 'bool'>
# <class 'float'>
# <class 'str'>

# %%
String3 = "MOnty" + " Pythgon"

# %%
print(type(String3))
# Out:
# <class 'str'>

# %%
Evennumbers = [2, 4, 6, 8, 10, 12, 14, 16, 18]
Temp = Evennumbers[1]+Evennumbers[3]
print(Evennumbers[1], Evennumbers[3], Evennumbers[7], Temp)
# Out:
# 4 8 16 12

# %%
Suitcase = ["sunglasses", "hat", "passport", "laptop", "suit", "shoes"]
print(Suitcase[1:], Suitcase[:4])
# Out:
# ['hat', 'passport', 'laptop', 'suit', 'shoes'] ['sunglasses', 'hat', 'passport', 'laptop']

# %%
xlist = [1, 2, 3, 4]
for x in xlist:
     print(x + 1)
# Out:
# 2
# 3
# 4
# 5

# %%
nlist = [8, 92, 79, 55, 23, 17, 4, 45, 63, 9, 100]
threshold = input('Type Threshold: ')
if (max(nlist) > int(threshold)):
    print('Great')
else:
    print('Not great')
# Out:
# Type Threshold:  55
# Great

# %%
fruitlist = ['apple', 'pear', 'banana']
fruitlist_new = []
for x in fruitlist:
     fruitlist_new.append(x[0:3])
print(fruitlist_new)
# Out:
# ['app', 'pea', 'ban']

# %%
#Create Lists
examples1 = ['abab', 'xyz', 'aa', 'x', 'bcb']
examples2 = ['', 'x', 'xy', 'xyx', 'xx']
examples3 = ['aaa', 'be', 'abc', 'hello']

# Create a sample that concatinates the three strings

sample = examples1 + examples2 + examples3

# Create a function that iterates over the sample, printing strings of 3 or more while evaluating if the characters at the beginning of the string and the end are the same. 

def output():
    for i in sample:
        if(len(i)>=3 and i[0] == i[-1]):
           print(i)

output()
# Out:
# bcb
# xyx
# aaa

# %%
#Starting muckrakers
import csv
import numpy as np

#Define a function that combs
def get_scores(source_file):
    SAT_list = []

    with open(source_file, 'r') as csv_file:
        score_reader = csv.reader(csv_file, dialect='excel', delimiter='\t')

        lines = [line for line in score_reader]
        
    for each_line in lines:
        state = str(each_line[0])
        mean_verbal = int(each_line[1])
        mean_math = int(each_line[2])
        SAT_list.append([state, mean_verbal, mean_math])
    return SAT_list

#infile = 'state_satscores_2004.tsv'

# %%
#Executing read-in
import os
print(os.getcwd())
# Out:
# C:\Users\bendi\OneDrive\Documents\My.Master.Plan\IST 652 Scripting for Data\Assignments\Lab3

# %%
source_file = 'C:\Users\bendi\OneDrive\Documents\My.Master.Plan\IST 652 Scripting for Data\Assignments\Quiz1\state_satscores_2004.tsv'
# Out:
#   Cell In[31], line 1
#     source_file = 'C:\Users\bendi\OneDrive\Documents\My.Master.Plan\IST 652 Scripting for Data\Assignments\Quiz1\state_satscores_2004.tsv'
#                                                                                                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
SAT_list = get_scores(source_file)
print(SAT_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 SAT_list = get_scores(source_file)
#       2 print(SAT_list)
#
# Cell In[22], line 9, in get_scores(source_file)
#       6 def get_scores(source_file):
#       7     SAT_list = []
# ----> 9     with open(source_file, 'r') as csv_file:
#      10         score_reader = csv.reader(csv_file, dialect='excel', delimiter='\t')
#      12         lines = [line for line in score_reader]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state_satscores_2004.tsv'
