# %%
print(chr(15))

# %%
15
# Out:
# 15

# %%
print(chr(0xFF))
# Out:
# ÿ

# %%
0xFF
# Out:
# 255

# %%
0x75
# Out:
# 117

# %%
'\u0394'
# Out:
# 'Δ'

# %%
"\U00000394"
# Out:
# 'Δ'

# %%
"\N{GREEK CAPITAL LETTER DELTA}"
# Out:
# 'Δ'

# %%
b'\xFFab'
# Out:
# b'\xffab'

# %%
type(b'ab')
# Out:
# bytes

# %%
type(b'\xFFab')
# Out:
# bytes

# %%
len(b'\xFFab')
# Out:
# 3

# %%
u=chr(40960) + 'abcd' + chr(1972)

# %%
type(u)
# Out:
# str

# %%
u
# Out:
# 'ꀀabcd\u07b4'

# %%
print(u)
# Out:
# ꀀabcd޴

# %%
u.encode('ascii','ignore')
# Out:
# b'abcd'

# %%
u.encode('ascii','replace')
# Out:
# b'?abcd?'

# %%
u.encode('ascii', 'xmlcharrefreplace')
# Out:
# b'&#40960;abcd&#1972;'

# %%
u.encode('ascii', 'backslashreplace')
# Out:
# b'\\ua000abcd\\u07b4'

# %%
### I do not think I am smart enough to understand everything that I just did....
