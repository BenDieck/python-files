# %% [markdown]
# Write a program to print the cube of all numbers from 1 to 6. A cube of a number is x3 (x *x*x).
# Use a loop (either a for or while loop) to go through the numbers and print out the
# cube of each number. Your output should look like this:
# 1 cube is 1
# 2 cube is 8
# Etc.

# %%
def cubit(n):
    return [x**3 for x in range(1, n + 1)]

# %%
cubed = cubit(6)
for idx, cube in enumerate(cubed):
    print(f"The cube of {1 + idx} is {cube}")
# Out:
# The cube of 1 is 1
# The cube of 2 is 8
# The cube of 3 is 27
# The cube of 4 is 64
# The cube of 5 is 125
# The cube of 6 is 216

# %%
g = cubit(10)

# %%
g
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
