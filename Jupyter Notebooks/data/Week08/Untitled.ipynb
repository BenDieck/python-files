# %% [markdown]
# 1. open a file and create an in-memory object from the file contents
# 2. restructure source information
# 3. transform in-memory
# 4. analyze information
#     a. graphs / charts
#     b. model

# %%
def get_data_from_file(file_location):
    file_handle = os.open_file(file_location)
    file_handle.close()
    return 1

def restructure_data(unstructured_data):
    return 2

def transform_data(structured_data):
    return 3

def graph_data(transformed_data):
    # plot the data

# %%
file_location = '../data/file.txt'
raw_data = get_data_from_file(file_location)
structured_data = restructure_data(raw_data)
transformed_data = transform_data(structured_data)
graph_data(transformed_data)
