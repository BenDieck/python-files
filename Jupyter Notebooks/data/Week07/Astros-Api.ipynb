# %% [markdown]
# Python API tutorial
# see: https://www.dataquest.io/blog/python-api-tutorial/

# %%
#!pip install requests
import requests

# %%
# try accessing a valid API server using an invalid URL
api_url = "http://api.open-notify.org/this-api-doesnt-exist"
response = requests.get(api_url)

# %%
# display the results
print(response.status_code)

if response.status_code == 200:
    print(response.json())
# Out:
# 404

# %%
api_url = "http://api.open-notify.org/astros.json"
response = requests.get(api_url)
# display the results
print(response.status_code)

if response.status_code == 200:
    print(response.json())
# Out:
# 200
# {'number': 10, 'people': [{'name': 'Sergey Prokopyev', 'craft': 'ISS'}, {'name': 'Dmitry Petelin', 'craft': 'ISS'}, {'name': 'Frank Rubio', 'craft': 'ISS'}, {'name': 'Stephen Bowen', 'craft': 'ISS'}, {'name': 'Warren Hoburg', 'craft': 'ISS'}, {'name': 'Sultan Alneyadi', 'craft': 'ISS'}, {'name': 'Andrey Fedyaev', 'craft': 'ISS'}, {'name': 'Jing Haiping', 'craft': 'Tiangong'}, {'name': 'Gui Haichow', 'craft': 'Tiangong'}, {'name': 'Zhu Yangzhu', 'craft': 'Tiangong'}], 'message': 'success'}

# %%
import json

response = requests.get("http://api.open-notify.org/iss-now.json")
 
obj = response.json()
print(obj)

lat = obj['iss_position']['latitude']
lon = obj['iss_position']['longitude']

print(f"Latitude: {lat}, longitude: {lon}")
# Out:
# {'message': 'success', 'timestamp': 1692111863, 'iss_position': {'latitude': '3.3981', 'longitude': '-153.1217'}}
# Latitude: 3.3981, longitude: -153.1217
