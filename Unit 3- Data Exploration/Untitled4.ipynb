# %%
stock = {"banana":6,"apple":0,"orange":32,"pear":15}

prices = {"banana":4,"apple":2,"orange":1.5,"pear":3}

# %%
#Index the dictionary value for orange
stock['orange']
# Out:
# 32

# %%
#Add dictionary item "cherry" to the dictionary "stock". 
stock["cherry"]=14

# %%
#Verify cherry is in the dictionary.
print(stock)
# Out:
# {'banana': 6, 'apple': 0, 'orange': 32, 'pear': 15, 'cherry': 14}

# %%
#Write a loop that will print all keys with value
for key in stock:
        print(key,stock[key])
# Out:
# banana 6
# apple 0
# orange 32
# pear 15
# cherry 14
