# %%
phonelist = {}
phonelist = {'Anita Break':'910-5689','G. Dan Itslate':'518-4659','Mike Stufismissin':'568-9999','Ali Wan Issanap':'478-3568'
            , 'Evan Thedeadsleep' : '231-7812'}

# %%
for key in sorted(phonelist):
    print(key, phonelilst[key])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 for key in sorted(phonelist):
# ----> 2     print(key, phonelilst[key])
#
# NameError: name 'phonelilst' is not defined
