# %%
def fred():
    print("Zap")

# %%
def jane():
    print("ABC")

# %%
#My answer is D because that is the answer. 
jane()
fred()
jane()
# Out:
# ABC
# Zap
# ABC

# %%
def paycomp(hours,rate):
    salary = hours * rate
    return salary

# %%
paycomp(8,45.87)
# Out:
# 366.96
