# %%
# import the pymongo library
from pymongo import MongoClient

# %%
# connect to a mongo client using a host name and port
# use localhost to connect to your own device and
# port 27017 by default
host_name = 'local host'
host_port = 27017
client = MongoClient(host_name, host_port)

# %%
# show existing databases
print(client.list_database_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[14], line 2
#       1 # show existing databases
# ----> 2 print(client.list_database_names())
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1885, in MongoClient.list_database_names(self, session, comment)
#    1867 def list_database_names(
#    1868     self,
#    1869     session: Optional[client_session.ClientSession] = None,
#    1870     comment: Optional[Any] = None,
#    1871 ) -> List[str]:
#    1872     """Get a list of the names of all databases on the connected server.
#    1873
#    1874     :Parameters:
#    (...)
#    1883     .. versionadded:: 3.6
#    1884     """
# -> 1885     return [doc["name"] for doc in self.list_databases(session, nameOnly=True, comment=comment)]
#
# ...

# %%
client.close()
