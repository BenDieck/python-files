# %%
import urllib.request
import json
earthquake_url = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.geojson"

# %%
response = urllib.request.urlopen(earthquake_url)
json_string = response.read().decode('utf-8')

# %%
eq_parsed_json = json.loads(json_string)
type(eq_parsed_json)
# Out:
# dict

# %%
print(eq_parsed_json.keys())

print(eq_parsed_json['type'])
print(eq_parsed_json['metadata'])
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])
# FeatureCollection
# {'generated': 1637718157000, 'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.geojson', 'title': 'USGS Significant Earthquakes, Past Month', 'status': 200, 'api': '1.10.3', 'count': 7}

# %%
title = eq_parsed_json['metadata']['title']
print(title)

quakelist = eq_parsed_json['features']
len(quakelist)
# Out:
# USGS Significant Earthquakes, Past Month
# 7

# %%
quake1 = quakelist[0]
print(type(quake1))
print(quake1.keys())
# Out:
# <class 'dict'>
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
print(json.dumps(quake1, indent=2))
# Out:
# {
#   "type": "Feature",
#   "properties": {
#     "mag": 4,
#     "place": "7 km S of Williamsville, Missouri",
#     "time": 1637203983820,
#     "updated": 1637709296915,
#     "tz": null,
#     "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nm60363582",
#     "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nm60363582.geojson",
#     "felt": 5204,
#     "cdi": 5.4,
#     "mmi": 4.838,
#     "alert": "green",
#     "status": "reviewed",
#     "tsunami": 0,
#     "sig": 786,
#     "net": "nm",
#     "code": "60363582",
#     "ids": ",nm60363582,us7000fuzj,",
#     "sources": ",nm,us,",
#     "types": ",dyfi,losspager,moment-tensor,origin,phase-data,shakemap,",
#     "nst": 99,
#     "dmin": 0.1577,
#     "rms": 0.23,
#     "gap": 44,
#     "magType": "mw",
#     "type": "earthquake",
#     "title": "M 4.0 - 7 km S of Williamsville, Missouri"
#   },
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       -90.543,
#       36.9076667,
#       16.46
#     ]
#   },
#   "id": "nm60363582"
# }
